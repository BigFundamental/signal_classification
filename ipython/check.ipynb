# %%
# %load_ext autoreload
# %autoreload 2

from filter import Filter
from feature_extrator import FeatureExtrator
# Out:
# ImportErrorTraceback (most recent call last)
# <ipython-input-2-3f2eac1c9aef> in <module>()
#       3
#       4 from filter import Filter
# ----> 5 from feature_extrator import FeatureExtrator
#
# ImportError: No module named feature_extrator

# %%
import numpy as np
import pandas as pd
from matplotlib import pyplot as plt
import scipy.signal as signal

# %matplotlib inline
# Out:
# /Users/changkong/tools/anaconda/lib/python2.7/site-packages/matplotlib/font_manager.py:273: UserWarning: Matplotlib is building the font cache using fc-list. This may take a moment.
#   warnings.warn('Matplotlib is building the font cache using fc-list. This may take a moment.')

# %%
signals = np.loadtxt("../../exp/a.txt")

# %%
feaExtractor = FeatureExtrator()
# Out:
# NameErrorTraceback (most recent call last)
# <ipython-input-5-9f17ca29b255> in <module>()
# ----> 1 feaExtractor = FeatureExtrator()
#
# NameError: name 'FeatureExtrator' is not defined

# %%
df1 = pd.Series(feaExtractor.guassianNormalize(signals[550:580]))
# Out:
# NameErrorTraceback (most recent call last)
# <ipython-input-6-fb22870d622c> in <module>()
# ----> 1 df1 = pd.Series(feaExtractor.guassianNormalize(signals[550:580]))
#
# NameError: name 'feaExtractor' is not defined

# %%
df1.plot()
# Out:
# NameErrorTraceback (most recent call last)
# <ipython-input-7-1a84cdfdea9b> in <module>()
# ----> 1 df1.plot()
#
# NameError: name 'df1' is not defined

# %%
feaExtractor.peakPointers(signals[190:200], 5, 0.3)
# Out:
# NameErrorTraceback (most recent call last)
# <ipython-input-8-a8456bdd163e> in <module>()
# ----> 1 feaExtractor.peakPointers(signals[190:200], 5, 0.3)
#
# NameError: name 'feaExtractor' is not defined

# %%
edges = feaExtractor.upwardsEdges(signals, 5, 0.2)
# Out:
# NameErrorTraceback (most recent call last)
# <ipython-input-9-3d09cdd1192b> in <module>()
# ----> 1 edges = feaExtractor.upwardsEdges(signals, 5, 0.2)
#
# NameError: name 'feaExtractor' is not defined

# %%
print edges
# Out:
# NameErrorTraceback (most recent call last)
# <ipython-input-10-87b561fa05a2> in <module>()
# ----> 1 print edges
#
# NameError: name 'edges' is not defined

# %%
medfilter_signals = feaExtractor.detectEdges(signals, 5, 0.2, 1)
# pd.Series(medfilter_signals).plot()
# Out:
# NameErrorTraceback (most recent call last)
# <ipython-input-11-9f87287b57c5> in <module>()
# ----> 1 medfilter_signals = feaExtractor.detectEdges(signals, 5, 0.2, 1)
#       2 # pd.Series(medfilter_signals).plot()
#
# NameError: name 'feaExtractor' is not defined

# %%
# print pd.Series(medfilter_signals[0:100]).plot()
# print pd.Series(feature)

# %%
print pd.Series(medfilter_signals[80:90]).plot()
# print pd.Series(feature)
# Out:
# NameErrorTraceback (most recent call last)
# <ipython-input-12-d0e91c66a67c> in <module>()
# ----> 1 print pd.Series(medfilter_signals[80:90]).plot()
#       2 # print pd.Series(feature)
#
# NameError: name 'medfilter_signals' is not defined

# %%
print medfilter_signals[80:90]

# %%
edges = feaExtractor.detectEdges(signals, 5, 0.2, 1)

# %%
print edges
# Out:
# NameErrorTraceback (most recent call last)
# <ipython-input-1-87b561fa05a2> in <module>()
# ----> 1 print edges
#
# NameError: name 'edges' is not defined

# %%
import sys
import BaseHTTPServer
from SimpleHTTPServer import SimpleHTTPRequestHandler


HandlerClass = SimpleHTTPRequestHandler
ServerClass  = BaseHTTPServer.HTTPServer
Protocol     = "HTTP/1.0"

# if sys.argv[1:]:
#     port = int(sys.argv[1])
# else:
#     port = 8000
port = 8000
server_address = ('127.0.0.1', port)

HandlerClass.protocol_version = Protocol
httpd = ServerClass(server_address, HandlerClass)

sa = httpd.socket.getsockname()
print "Serving HTTP on", sa[0], "port", sa[1], "..."
httpd.serve_forever()
# Out:
# Serving HTTP on 127.0.0.1 port 8000 ...

# %%
from BaseHTTPServer import HTTPServer, BaseHTTPRequestHandler
from SocketServer import ThreadingMixIn
import threading

class Handler(BaseHTTPRequestHandler):

    def do_GET(self):
        self.send_response(200)
        self.end_headers()
        message =  threading.currentThread().getName()
        self.wfile.write(message)
        self.wfile.write('\n')
        return

class ThreadedHTTPServer(ThreadingMixIn, HTTPServer):
    """Handle requests in a separate thread."""

if __name__ == '__main__':
    server = ThreadedHTTPServer(('localhost', 8080), Handler)
    print 'Starting server, use <Ctrl-C> to stop'
    server.serve_forever()

# %%
from signal_manager import SignalMgr
import numpy as np
import pandas as pd
from matplotlib import pyplot as plt

# %matplotlib inline
# %load_ext autoreload
# %autoreload 2

# %%
mgr = SignalMgr()

# %%
mgr.process('/Users/changkong/ML/Signal Classification/exp/a.txt')
# mgr.process('/Users/changkong/ML/Signal Classification/realData/no_peak.txt')
# Out:
# [ 0.8984375   0.9387207   0.85327148 ...,  0.79345703  0.69458008
#   0.56030273]
# {'reason': 0, 'stat': 0}

# %%
df1 = pd.DataFrame(np.genfromtxt('/Users/changkong/ML/Signal Classification/realData/no_peak.txt', unpack=True, skip_header=15, dtype=np.float32, delimiter=',', usecols=(0)))

# %%
df1[30:46].plot()

# %%
#dt, signals = np.genfromtxt('/Users/changkong/ML/Signal Classification/realData/1-ok-small.csv', unpack=True, skip_header=15, dtype=np.float32, delimiter=',', usecols=(0, 1))
signals = np.genfromtxt('/Users/changkong/ML/Signal Classification/realData/no_peak.txt', unpack=True, skip_header=15, dtype=np.float32, delimiter=',', usecols=(0))

df1 = pd.DataFrame(signals)

# %%
df1.plot()

# %%
from feature_extractor import FeatureExtractor
from classifier import Classifier
from signal_manager import SignalMgr
from filter import Filter
import numpy as np
import pandas as pd
from matplotlib import pyplot as plt
# %matplotlib inline

feaExtractor = FeatureExtractor()
classifier = Classifier()
sigMgr = SignalMgr()
# norm_signal = sigMgr.normalize_signals(signals)

# %%
peak_idx = feaExtractor.peakPointers(norm_signal, 11, 0.3)

# %%
print len(peak_idx)
# Out:
# 13

# %%
med_filterd_signals = Filter.medfilter(norm_signal, 13)
df_m = pd.DataFrame(med_filterd_signals)
df_m.plot()
# Out:
# NameErrorTraceback (most recent call last)
# <ipython-input-49-68f8ecd3e5dd> in <module>()
# ----> 1 med_filterd_signals = Filter.medfilter(norm_signal, 13)
#       2 df_m = pd.DataFrame(med_filterd_signals)
#       3 df_m.plot()
#
# NameError: name 'norm_signal' is not defined

# %%
peak_candidates = norm_signal - med_filterd_signals
df_res = pd.DataFrame(peak_candidates)
df_res.plot()

# %%
peaks = Filter.nms(peak_candidates, 5)
df_p = pd.DataFrame(peaks)
df_p.plot()

# %%
# fpath = '/Users/changkong/ML/Signal Classification/exp/e_diagnal_shoulder.txt'
# fpath = '/Users/changkong/ML/Signal Classification/exp/e_long_short.txt'
fpath = '/Users/changkong/ML/Signal Classification/exp/e_upside_down.txt'
signals = np.genfromtxt(fpath, unpack=True, skip_header=0, dtype=np.float32, delimiter=',', usecols=[0])
df = pd.DataFrame(signals)

# %%
df[500:1000].plot()

# %%
fpath = '/Users/changkong/ML/Signal Classification/exp/a.txt'
signals = np.genfromtxt(fpath, unpack=True, skip_header=0, dtype=np.float32, delimiter=',', usecols=[0])
df1 = pd.DataFrame(signals)

# %%
df1[500:1000].plot()

# %%
sigMgr.process('/Users/changkong/ML/Signal Classification/exp/e_upside_down.txt')
# Out:
# {'reason': 1, 'speed': 0, 'stat': 1}
